# %%
# !conda env list
# Out:
# # conda environments:
# #
# # * -> active
# # + -> frozen
#                          /Users/yugant/Data Science/Code/h501-gutenberg/.conda
# base                     /Users/yugant/miniconda3
# h501-gutenberg       *   /Users/yugant/miniconda3/envs/h501-gutenberg
# student-performance      /Users/yugant/miniconda3/envs/student-performance
# week0-webapp             /Users/yugant/miniconda3/envs/week0-webapp
