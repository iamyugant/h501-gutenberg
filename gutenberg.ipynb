# %%
# !conda env list
# Out:
# # conda environments:
# #
# # * -> active
# # + -> frozen
#                          /Users/hamzaalmani/Desktop/DATASCIENCE/Project/.conda
#                      *   /Users/hamzaalmani/Desktop/h501-gutenberg/.conda
# base                     /opt/miniconda3
# student-performance      /opt/miniconda3/envs/student-performance
